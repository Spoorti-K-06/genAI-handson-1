# %%
from transformers import pipeline

# %%
# !pip install tf_keras
# Out:
# Requirement already satisfied: tf_keras in c:\users\spooorti\appdata\local\programs\python\python313\lib\site-packages (2.20.1)
# Requirement already satisfied: tensorflow<2.21,>=2.20 in c:\users\spooorti\appdata\local\programs\python\python313\lib\site-packages (from tf_keras) (2.20.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\spooorti\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.21,>=2.20->tf_keras) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\spooorti\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.21,>=2.20->tf_keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\spooorti\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.21,>=2.20->tf_keras) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\spooorti\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.21,>=2.20->tf_keras) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\spooorti\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.21,>=2.20->tf_keras) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\spooorti\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.21,>=2.20->tf_keras) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\spooorti\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.21,>=2.20->tf_keras) (3.4.0)
# Requirement already satisfied: packaging in c:\users\spooorti\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.21,>=2.20->tf_keras) (25.0)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\spooorti\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.21,>=2.20->tf_keras) (6.31.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\spooorti\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.21,>=2.20->tf_keras) (2.32.4)
# Requirement already satisfied: setuptools in c:\users\spooorti\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.21,>=2.20->tf_keras) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\spooorti\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.21,>=2.20->tf_keras) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\spooorti\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.21,>=2.20->tf_keras) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\spooorti\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.21,>=2.20->tf_keras) (4.14.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\spooorti\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.21,>=2.20->tf_keras) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\spooorti\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.21,>=2.20->tf_keras) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\spooorti\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.21,>=2.20->tf_keras) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\spooorti\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.21,>=2.20->tf_keras) (3.13.1)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\spooorti\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.21,>=2.20->tf_keras) (2.2.3)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\spooorti\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.21,>=2.20->tf_keras) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\spooorti\appdata\local\programs\python\python313\lib\site-packages (from tensorflow<2.21,>=2.20->tf_keras) (0.5.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\spooorti\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf_keras) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\spooorti\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf_keras) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\spooorti\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf_keras) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\spooorti\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf_keras) (2025.7.14)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\spooorti\appdata\local\programs\python\python313\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf_keras) (3.10.1)
# Requirement already satisfied: pillow in c:\users\spooorti\appdata\local\programs\python\python313\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf_keras) (11.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\spooorti\appdata\local\programs\python\python313\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf_keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\spooorti\appdata\local\programs\python\python313\lib\site-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf_keras) (3.1.5)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\spooorti\appdata\local\programs\python\python313\lib\site-packages (from astunparse>=1.6.0->tensorflow<2.21,>=2.20->tf_keras) (0.46.3)
# Requirement already satisfied: rich in c:\users\spooorti\appdata\local\programs\python\python313\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf_keras) (14.1.0)
# Requirement already satisfied: namex in c:\users\spooorti\appdata\local\programs\python\python313\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf_keras) (0.1.0)
# Requirement already satisfied: optree in c:\users\spooorti\appdata\local\programs\python\python313\lib\site-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf_keras) (0.18.0)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\spooorti\appdata\local\programs\python\python313\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf_keras) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\spooorti\appdata\local\programs\python\python313\lib\site-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf_keras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\spooorti\appdata\roaming\python\python313\site-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf_keras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\spooorti\appdata\local\programs\python\python313\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf_keras) (0.1.2)

# %%
prompt = "The future of Artificial Intelligence is"

# %%
gen_bert = pipeline("text-generation", model="bert-base-uncased")
gen_bert(prompt, max_length=40)
# Out:
# If you want to use `BertLMHeadModel` as a standalone, add `is_decoder=True.`
# Device set to use cpu
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'The future of Artificial Intelligence is................................................................................................................................................................................................................................................................'}]

# %%
gen_roberta = pipeline("text-generation", model="roberta-base")
gen_roberta(prompt, max_length=40)
# Out:
# If you want to use `RobertaLMHeadModel` as a standalone, add `is_decoder=True.`
# Device set to use cpu
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'The future of Artificial Intelligence is'}]

# %%
gen_bart = pipeline("text-generation", model="facebook/bart-base")
gen_bart(prompt, max_length=40)
# Out:
# Some weights of BartForCausalLM were not initialized from the model checkpoint at facebook/bart-base and are newly initialized: ['lm_head.weight', 'model.decoder.embed_tokens.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Device set to use cpu
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'The future of Artificial Intelligence is predetermined A A Briggs await Hunterundred A A A Featuringnce obese obese obese ampl obese append obese obese int AHidden A Hunter Hunter Thompson ThompsonGeneral obese Briggs assertion Briggs international international internationalGeneralorb A obese obese A A Hunter enzyme exoner exoner exonerAL exonerundredundred obese jung international obesewasher endlessly obese obese international obese obese exoner obese conditions obese obeseExc obese obeseuration international Hunter obesewasheruration obese internationalurationundredHF international international obeseuration obese Gerry exoner archived obese exonerurationundred internationalYang//// obese obese archivedomorphic obese obese aboveRequiredYang Briggs obese obese Devon obese jungundred obese obeseundreduration archived Briggs obese Devonurationuration NEW archived obese Briggs archived obese international international salv international international Hunterien//// Hunter obeseundred archived archived obese obeseHF Briggsquerque Hunter Hunter international obese internationalforming international Goddard obese ampl Briggs international disrupting FeaturingHFundred Briggs obeseRequiredRequiredundred salvHFPLAY motoritansundred international obese NEWviksundredundredPLAY obesecharges Hunter salv obese archived archiveduration obese Coalition internationalundred international//// obese HunterRequired seven international internationalienurationuration internationalundredPLAY intenseundred obeseSharundredundredundredRequiredundred obesePGundredundred archived obeseundredundred Booth scenariosSharundred obese NEWPLAYundredPLAYundredundredOT obese obesePLAY obese obese////undred rail obese obeseien obeseundred obeseundredien obese ampl seven'}]

# %%
mask_bert = pipeline("fill-mask", model="bert-base-uncased")

mask_bert("The goal of Generative AI is to [MASK] new content.")
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Device set to use cpu
# [{'score': 0.539692759513855,
#   'token': 3443,
#   'token_str': 'create',
#   'sequence': 'the goal of generative ai is to create new content.'},
#  {'score': 0.15575766563415527,
#   'token': 9699,
#   'token_str': 'generate',
#   'sequence': 'the goal of generative ai is to generate new content.'},
#  {'score': 0.05405496060848236,
#   'token': 3965,
#   'token_str': 'produce',
#   'sequence': 'the goal of generative ai is to produce new content.'},
#  {'score': 0.044515229761600494,
#   'token': 4503,
#   'token_str': 'develop',
#   'sequence': 'the goal of generative ai is to develop new content.'},
#  {'score': 0.017577484250068665,
#   'token': 5587,
#   'token_str': 'add',
#   'sequence': 'the goal of generative ai is to add new content.'}]

# %%
mask_roberta = pipeline("fill-mask", model="roberta-base")

mask_roberta("The goal of Generative AI is to <mask> new content.")
# Out:
# Device set to use cpu
# [{'score': 0.37113118171691895,
#   'token': 5368,
#   'token_str': ' generate',
#   'sequence': 'The goal of Generative AI is to generate new content.'},
#  {'score': 0.3677138090133667,
#   'token': 1045,
#   'token_str': ' create',
#   'sequence': 'The goal of Generative AI is to create new content.'},
#  {'score': 0.08351466804742813,
#   'token': 8286,
#   'token_str': ' discover',
#   'sequence': 'The goal of Generative AI is to discover new content.'},
#  {'score': 0.02133519947528839,
#   'token': 465,
#   'token_str': ' find',
#   'sequence': 'The goal of Generative AI is to find new content.'},
#  {'score': 0.01652175933122635,
#   'token': 694,
#   'token_str': ' provide',
#   'sequence': 'The goal of Generative AI is to provide new content.'}]

# %%
mask_bart = pipeline("fill-mask", model="facebook/bart-base")

mask_bart("The goal of Generative AI is to <mask> new content.")
# Out:
# Device set to use cpu
# [{'score': 0.07461544126272202,
#   'token': 1045,
#   'token_str': ' create',
#   'sequence': 'The goal of Generative AI is to create new content.'},
#  {'score': 0.06571853160858154,
#   'token': 244,
#   'token_str': ' help',
#   'sequence': 'The goal of Generative AI is to help new content.'},
#  {'score': 0.060880184173583984,
#   'token': 694,
#   'token_str': ' provide',
#   'sequence': 'The goal of Generative AI is to provide new content.'},
#  {'score': 0.035935722291469574,
#   'token': 3155,
#   'token_str': ' enable',
#   'sequence': 'The goal of Generative AI is to enable new content.'},
#  {'score': 0.03319481760263443,
#   'token': 1477,
#   'token_str': ' improve',
#   'sequence': 'The goal of Generative AI is to improve new content.'}]

# %%
context = "Generative AI poses significant risks such as hallucinations, bias, and deepfakes."
question = "What are the risks?"

# %%
qa_bert = pipeline("question-answering", model="bert-base-uncased")

qa_bert(question=question, context=context)
# Out:
# Some weights of BertForQuestionAnswering were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Device set to use cpu
# {'score': 0.004913331940770149,
#  'start': 32,
#  'end': 61,
#  'answer': 'risks such as hallucinations,'}

# %%
qa_roberta = pipeline("question-answering", model="roberta-base")

qa_roberta(question=question, context=context)
# Out:
# Some weights of RobertaForQuestionAnswering were not initialized from the model checkpoint at roberta-base and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Device set to use cpu
# {'score': 0.008558643516153097,
#  'start': 32,
#  'end': 81,
#  'answer': 'risks such as hallucinations, bias, and deepfakes'}

# %%
qa_bart = pipeline("question-answering", model="facebook/bart-base")

qa_bart(question=question, context=context)
# Out:
# Some weights of BartForQuestionAnswering were not initialized from the model checkpoint at facebook/bart-base and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Device set to use cpu
# {'score': 0.043700157664716244, 'start': 72, 'end': 81, 'answer': 'deepfakes'}
